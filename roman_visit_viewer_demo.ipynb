# %%
import roman_visit_viewer as viewer

# %%
filename = "V1010101001001001002.vst"

visit_parser = viewer.VisitFileParser(filename)

plot_all = False
if plot_all:
    for block in visit_parser:
        block.plot()
else:
    viewer.plot_manager( visit_parser, exp_num = 3)
# Out:
# Requested exposure 3 but visit file contains only 2 exposures; defaulting to first exposure
